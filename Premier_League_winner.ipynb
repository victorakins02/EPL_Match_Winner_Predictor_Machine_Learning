# %% [markdown]
# <a href="https://colab.research.google.com/github/victorakins02/Premier-League-Predictor/blob/main/Premier_League_winner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# ...

# %%
matches.shape #number of rows , columns
# Out:
# (1389, 27)

# %%
38 * 20 * 2 #(38 games, 20 teams, 2 years = total number of games played). Some are missing if we only have 1389 rows
# Out:
# 1520

# %%
matches["team"].value_counts()
# 3 teams are relagated each year, so they will have less games.
# Strange that Liverpool has so little
# Out:
# team
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Brighton and Hove Albion    72
# Southampton                 72
# Tottenham Hotspur           71
# Manchester City             71
# Leeds United                71
# Wolverhampton Wanderers     71
# Arsenal                     71
# Crystal Palace              71
# Burnley                     71
# Chelsea                     70
# Aston Villa                 70
# Leicester City              70
# Everton                     70
# West Bromwich Albion        38
# Fulham                      38
# Liverpool                   38
# Sheffield United            38
# Brentford                   34
# Norwich City                33
# Watford                     33
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"]
# Seems like we only have 2021 data for Liverpool
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W  4.0
# 2   2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away      W  2.0
# 4   2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home      W  3.0
# 6   2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L  2.0
# 7   2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D  2.0
# 9   2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 11  2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W  2.0
# 13  2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D  1.0
# 14  2020-11-22  19:15  Premier League   Matchweek 9  Sun  Home      W  3.0
# 16  2020-11-28  12:30  Premier League  Matchweek 10  Sat  Away      D  1.0
# 18  2020-12-06  19:15  Premier League  Matchweek 11  Sun  Home      W  4.0
# ...

# %%
matches["round"].value_counts()
# Data is for seasons 21/22 and 22/23.
# Each week has 20 games and this is over 2 years so 1 week is missing. Likely from the missinng Liverpool Season.
# Data seems to not be complete. Collected mid season??
# Out:
# round
# Matchweek 1     39
# Matchweek 2     39
# Matchweek 3     39
# Matchweek 4     39
# Matchweek 5     39
# Matchweek 6     39
# Matchweek 7     39
# Matchweek 8     39
# Matchweek 9     39
# Matchweek 10    39
# Matchweek 11    39
# Matchweek 12    39
# Matchweek 13    39
# Matchweek 14    39
# Matchweek 15    39
# Matchweek 16    39
# Matchweek 17    39
# Matchweek 19    39
# Matchweek 20    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 34    39
# Matchweek 29    39
# Matchweek 31    39
# Matchweek 26    39
# Matchweek 28    39
# Matchweek 32    39
# Matchweek 18    37
# Matchweek 21    37
# Matchweek 22    37
# Matchweek 27    37
# Matchweek 30    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
matches.dtypes
# For machiene learning, we need numerical data.
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])
# Changed to numerical vale we can now use

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes
# Changing venue from string into a category then into numerical values.
# Trying to look into home/away advantage

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
# Assign each opponent a value

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex = True).astype("int")
# what hour did each team play

# %%
matches["day_code"] = matches["date"].dt.dayofweek
# Assign numerical values to the days

# %%
matches["target"] = (matches["result"] == "W").astype("int")
# 1 if team won, 0 if draw/loss

# %%
from sklearn.ensemble import RandomForestClassifier
# Picks up non-linearity in data
# "opp_code" doesn't have a linear relationship

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
# n_estimators is number of decision trees we want to train. The more trees, the more accurate
# randomforest is a series of decision trees but each tree has different parameters
# min_samples_split is the number of samples before we split node. Higher value means likely to overfit, but lower accuary on training data.
# randomforest has lots of random parameters, so if we re-run the randomforest, we get the same results.

# %%
train = matches[matches["date"] < '2022-01-01']
# our training data is 2021 season

# %%
test = matches[matches["date"] > '2022-01-01']
# our test data is 2022 season

# %%
predictors = ["opp_code", "venue_code", "hour", "day_code"]
# we will try predict the winner of each game based of these parameters

# %%
rf.fit(train[predictors], train["target"])
# use our Randomforest to train our model.
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])
# Now we plan to compare again our test data

# %%
from sklearn.metrics import accuracy_score
# importing accuracy_score to test the accuracy of our training data

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# we are 60% accurate
# Out:
# 0.6086956521739131

# %%
combined = pd.DataFrame(dict(actual = test["target"], prediction=preds))
#Looking for when our accuracy is high or low.
#Data frame combines out actual and predicted values

# %%
pd.crosstab(index=combined["actual"], columns = combined["prediction"])
# what happened when we predicted a 0 or 1
# we were right about the loses 146 times and wrong 82 times. This is accurate
# we were right about the wins 26 times and wrong 22 times. This is not accurate
# Out:
# prediction    0   1
# actual
# 0           146  26
# 1            82  22

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# new metric
# when we predicted a win, what percentage of the time did the team actually win
# so we only predicted correct wins 46% of the time
# how can we improve
# Out:
# 0.4583333333333333

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City")

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 54 2021-05-01  12:30  Premier League  Matchweek 34  Sat  Away      W  2.0
# 56 2021-05-08  17:30  Premier League  Matchweek 35  Sat  Home      L  1.0
# 57 2021-05-14  20:00  Premier League  Matchweek 36  Fri  Away      W  4.0
# 58 2021-05-18  19:00  Premier League  Matchweek 37  Tue  Away      L  2.0
# 59 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  5.0
#
#      ga        opponent  ...   fk   pk  pkatt  season             team  \
# ...

# %%
def rolling_averages(group, cols, new_cols):
  group = group.sort_values("date") # sort by date
  rolling_stats = group[cols].rolling(3, closed = 'left').mean() #rolling avg
  group[new_cols] = rolling_stats # assign back to dataframe with new name
  group = group.dropna(subset=new_cols) # drop missing values
  return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
# goals for, goals against, shots takens, shots on target, distance traveled, free kicks, penalty kick, penalty kick attempts
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
#collected rolling averages of each stat
# Out:
#          date   time            comp         round  day venue result   gf  \
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W  1.0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W  1.0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D  1.0
# 12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 42 2022-03-14  20:00  Premier League  Matchweek 29  Mon  Away      D  0.0
# 44 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away      W  2.0
# 46 2022-04-10  16:30  Premier League  Matchweek 32  Sun  Home      D  2.0
# 49 2022-04-20  20:00  Premier League  Matchweek 30  Wed  Home      W  3.0
# 50 2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home      W  5.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x : rolling_averages(x, cols, new_cols))
# first group everything by team
# apply the function to each team in dataset to get rolling averages of each team
# Out:
# /tmp/ipython-input-1636103718.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x : rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 32 2022-03-13  14:00  Premier League  Matchweek 29
#                         33 2022-03-18  20:00  Premier League  Matchweek 30
#                         34 2022-04-02  15:00  Premier League  Matchweek 31
#                         35 2022-04-08  20:00  Premier League  Matchweek 32
#                         36 2022-04-24  14:00  Premier League  Matchweek 34
#
# ...

# %%
matches_rolling = matches_rolling.droplevel("team")
#just get rid of team column for convenience

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 32 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 33 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 34 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 35 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 36 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
#      ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])
#give each row its own index
#unique values for each index
